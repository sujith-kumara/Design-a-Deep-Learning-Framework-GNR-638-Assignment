# %%
import train
from custom_NN import load_dataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from train import train
#       2 from custom_NN import load_dataset
#
# ModuleNotFoundError: No module named 'train'

# %%
if __name__ == "__main__":

    path = r"C:\Users\Mystical\Documents\GNR_638_DL\Assignmet_1\data_1\data_1" # Update this path

    batch = 8
    epoch = 1
    lr = 0.01

    # 1. Load Data
    x_all, y_all, load_time = load_dataset(path)
    X_train, X_test, y_train, y_test = train.train_test_split(x_all, y_all, test_size=0.2, seed=42)
    train.train(X_train, y_train, batch, epoch, lr)
